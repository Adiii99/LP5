# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("boston.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO       B  LSTAT  Price
# 0  296.0     15.3  396.90   4.98   24.0
# 1  242.0     17.8  396.90   9.14   21.6
# 2  242.0     17.8  392.83   4.03   34.7
# 3  222.0     18.7  394.63   2.94   33.4
# 4  222.0     18.7  396.90   5.33   36.2

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS',
#        'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'Price'],
#       dtype='object')

# %%
data.head(n=10)
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0
# 5           5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0
# 6           6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0
# 7           7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0
# 8           8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0
# 9           9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0
#
#      TAX  PTRATIO       B  LSTAT  Price
# 0  296.0     15.3  396.90   4.98   24.0
# 1  242.0     17.8  396.90   9.14   21.6
# 2  242.0     17.8  392.83   4.03   34.7
# 3  222.0     18.7  394.63   2.94   33.4
# 4  222.0     18.7  396.90   5.33   36.2
# 5  222.0     18.7  394.12   5.21   28.7
# 6  311.0     15.2  395.60  12.43   22.9
# 7  311.0     15.2  396.90  19.15   27.1
# 8  311.0     15.2  386.63  29.93   16.5
# 9  311.0     15.2  386.71  17.10   18.9

# %%
data.shape
# Out:
# (506, 15)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# CRIM          0
# ZN            0
# INDUS         0
# CHAS          0
# NOX           0
# RM            0
# AGE           0
# DIS           0
# RAD           0
# TAX           0
# PTRATIO       0
# B             0
# LSTAT         0
# Price         0
# dtype: int64

# %%
data.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# std      0.702617   28.148861    2.105710    8.707259  168.537116    2.164946
# min      3.561000    2.900000    1.129600    1.000000  187.000000   12.600000
# 25%      5.885500   45.025000    2.100175    4.000000  279.000000   17.400000
# 50%      6.208500   77.500000    3.207450    5.000000  330.000000   19.050000
# 75%      6.623500   94.075000    5.188425   24.000000  666.000000   20.200000
# max      8.780000  100.000000   12.126500   24.000000  711.000000   22.000000
#
#                 B       LSTAT       Price
# count  506.000000  506.000000  506.000000
# mean   356.674032   12.653063   22.532806
# std     91.294864    7.141062    9.197104
# min      0.320000    1.730000    5.000000
# 25%    375.377500    6.950000   17.025000
# 50%    391.440000   11.360000   21.200000
# 75%    396.225000   16.955000   25.000000
# max    396.900000   37.970000   50.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   CRIM        506 non-null    float64
#  2   ZN          506 non-null    float64
#  3   INDUS       506 non-null    float64
#  4   CHAS        506 non-null    float64
#  5   NOX         506 non-null    float64
#  6   RM          506 non-null    float64
#  7   AGE         506 non-null    float64
#  8   DIS         506 non-null    float64
#  9   RAD         506 non-null    float64
#  10  TAX         506 non-null    float64
#  11  PTRATIO     506 non-null    float64
#  12  B           506 non-null    float64
#  13  LSTAT       506 non-null    float64
#  14  Price       506 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 59.4 KB

# %%
import seaborn as sns

# %%
sns.histplot(data["Price"])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.boxplot(data["Price"])
# Out:
# <Axes: ylabel='Price'>

# %%
from sklearn.preprocessing import StandardScaler
# Split the data into input and output variables
X = data.drop('Price', axis=1)
y =data['Price']
# Scale the input features
scaler =StandardScaler()
X =scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
# Splitthe data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print('Training set shape:', X_train.shape, y_train.shape)
print('Testing set shape:', X_test.shape, y_test.shape)
# Out:
# Training set shape: (354, 14) (354,)
# Testing set shape: (152, 14) (152,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
# Define the model architecture
model = Sequential()

# %%
model.add(Dense(128,activation = 'relu',input_dim =14)) #input layer
model.add(Dense(64,activation = 'relu')) #hidden layer 1
model.add(Dense(32,activation = 'relu')) #hidden layer 2
model.add(Dense(16,activation = 'relu')) #hidden layer 3
model.add(Dense(1)) #output layer

# %%
# Display the model summary
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 128)               1920
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 16)                528
#
#  dense_9 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 12801 (50.00 KB)
# Trainable params: 12801 (50.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Compile the model
model.compile(optimizer = 'adam',loss ='mean_squared_error',metrics=['mae']) #mae - mean absolute error
x_val=X_train
y_val=y_train

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 1s 1s/step - loss: 641.2021 - mae: 23.4849 - val_loss: 633.7028 - val_mae: 23.3412
# Epoch 2/20
# 1/1 [==============================] - 0s 59ms/step - loss: 633.7028 - mae: 23.3412 - val_loss: 628.1395 - val_mae: 23.2340
# Epoch 3/20
# 1/1 [==============================] - 0s 41ms/step - loss: 628.1394 - mae: 23.2340 - val_loss: 624.1013 - val_mae: 23.1561
# Epoch 4/20
# 1/1 [==============================] - 0s 64ms/step - loss: 624.1013 - mae: 23.1561 - val_loss: 621.2504 - val_mae: 23.1001
# Epoch 5/20
# 1/1 [==============================] - 0s 38ms/step - loss: 621.2504 - mae: 23.1001 - val_loss: 619.0847 - val_mae: 23.0573
# Epoch 6/20
# 1/1 [==============================] - 0s 39ms/step - loss: 619.0847 - mae: 23.0573 - val_loss: 617.2762 - val_mae: 23.0217
# Epoch 7/20
# 1/1 [==============================] - 0s 41ms/step - loss: 617.2762 - mae: 23.0217 - val_loss: 615.8574 - val_mae: 22.9928
# Epoch 8/20
# 1/1 [==============================] - 0s 38ms/step - loss: 615.8575 - mae: 22.9928 - val_loss: 614.6346 - val_mae: 22.9672
# Epoch 9/20
# 1/1 [==============================] - 0s 38ms/step - loss: 614.6347 - mae: 22.9672 - val_loss: 613.4634 - val_mae: 22.9434
# Epoch 10/20
# 1/1 [==============================] - 0s 38ms/step - loss: 613.4635 - mae: 22.9434 - val_loss: 612.3091 - val_mae: 22.9204
# Epoch 11/20
# 1/1 [==============================] - 0s 39ms/step - loss: 612.3091 - mae: 22.9204 - val_loss: 611.1158 - val_mae: 22.8970
# Epoch 12/20
# 1/1 [==============================] - 0s 39ms/step - loss: 611.1157 - mae: 22.8970 - val_loss: 609.8234 - val_mae: 22.8717
# Epoch 13/20
# 1/1 [==============================] - 0s 37ms/step - loss: 609.8234 - mae: 22.8717 - val_loss: 608.4045 - val_mae: 22.8441
# Epoch 14/20
# 1/1 [==============================] - 0s 37ms/step - loss: 608.4045 - mae: 22.8441 - val_loss: 606.8359 - val_mae: 22.8135
# Epoch 15/20
# 1/1 [==============================] - 0s 39ms/step - loss: 606.8359 - mae: 22.8135 - val_loss: 605.0962 - val_mae: 22.7795
# Epoch 16/20
# 1/1 [==============================] - 0s 39ms/step - loss: 605.0962 - mae: 22.7795 - val_loss: 603.1721 - val_mae: 22.7417
# Epoch 17/20
# 1/1 [==============================] - 0s 59ms/step - loss: 603.1721 - mae: 22.7417 - val_loss: 601.0666 - val_mae: 22.7003
# Epoch 18/20
# 1/1 [==============================] - 0s 42ms/step - loss: 601.0666 - mae: 22.7003 - val_loss: 598.7499 - val_mae: 22.6546
# Epoch 19/20
# 1/1 [==============================] - 0s 39ms/step - loss: 598.7498 - mae: 22.6546 - val_loss: 596.2068 - val_mae: 22.6044
# Epoch 20/20
# 1/1 [==============================] - 0s 47ms/step - loss: 596.2068 - mae: 22.6044 - val_loss: 593.4038 - val_mae: 22.5487

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 6ms/step - loss: 541.8475 - mae: 21.6157
